# %%
## my opinion about happiness
ice_cream_rating=7
sleeping_rating=7

# %%
first_name=input('What is your first name?')
last_name=input('What is your last name?')
my_name=first_name+str(' ')+last_name
print(my_name)
# Out:
# What is your first name? Felix
# What is your last name? Pfluger
# Felix Pfluger

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2

# %% [markdown]
# ### Checking data types
# print(type(happiness_rating),\
#       type(sleeping_rating),type(ice_cream_rating))
#
#
# My name is Dave and I give eating ice cream a score of 9 out of 10!
# I am Dave Whipp and my sleeping enjoyment rating is 8 / 10!
# Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %!

# %%
print('My name is ',my_name,'and I give eating ice cream a score of',ice_cream_rating, 'out of 10!',
    '\nI am',first_name,'and my sleeping enjoyment rating is',sleeping_rating,'/ 10!',
     '\nBased on the factors above, my happiness rating is',happiness_rating,'out of 10, or',float(happiness_rating*10),'%!')
# Out:
# My name is  Felix Pfluger and I give eating ice cream a score of 7 out of 10!
# I am Felix and my sleeping enjoyment rating is 7 / 10!
# Based on the factors above, my happiness rating is 7.0 out of 10, or 70.0 %!
